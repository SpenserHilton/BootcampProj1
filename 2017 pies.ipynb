# %%
import pandas as pd
import numpy as np
import csv
import matplotlib

csv_path="2017topten.csv"
orig_df = pd.read_csv(csv_path)
orig_df.head(10)
# Out:
#                 Model   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 1   Chevrolet Bolt EV  1162   952   918  1292  1566  1642  1911  2101  2632
# 2      Tesla Model X*   150   800  2150   115  1730  2200  1650  1515  3120
# 0      Tesla Model S*   900  1150  3450  1125  1620  2350  1425  2150  4860
# 3  Toyota Prius Prime  1366  1362  1618  1819  1908  1619  1645  1820  1899
# 4      Chevrolet Volt  1611  1820  2132  1801  1811  1145  1518  1445  1453
# 5         Nissan LEAF   112  1031  1418  1063  1392  1506  1283  1154  1055
# 6  Ford Fusion Energi   606   831  1002   905  1000   101   103   162   163
# 7   Ford C-Max Energi   413   639   662   720   950   936   844   105   683
# 8              BMW i3   382   318   103   516   506   561   601   504   538
# 9         Fiat 500e**   152   590   185   541   473   359   395   290   285
#
#     OCT   NOV   DEC  Total
# 1  2181  2981  3227  23291
# 2   850  1815  3300  21315
# 0  1120  1335  4975  21060
# ...
