# %%
#Yearly dataset, import from xlsx
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
csv_path= "2017-sales.csv"
sales_df = pd.read_csv(csv_path)
sales_df.head(42)
# Out:
#                        2017-US    JAN    FEB    MAR    APR    MAY    JUN  \
# 0               Tesla Model S*    900  1,150  3,450  1,125  1,620  2,350
# 1            Chevrolet Bolt EV  1,162    952    918  1,292  1,566  1,642
# 2               Tesla Model X*    150    800  2,150    115  1,730  2,200
# 3           Toyota Prius Prime  1,366  1,362  1,618  1,819  1,908  1,619
# 4               Chevrolet Volt  1,611  1,820  2,132  1,801  1,811  1,145
# 5                  Nissan LEAF    112  1,031  1,418  1,063  1,392  1,506
# 6           Ford Fusion Energi    606    831  1,002    905  1,000    101
# 7            Ford C-Max Energi    413    639    662    720    950    936
# 8                       BMW i3    382    318    103    516    506    561
# 9                  Fiat 500e**    152    590    185    541    473    359
# 10            BMW X5 xDrive40e    262    275    397    291    433    488
# 11  Chrysler Pacifica Hybrid**     12      0      0    335    705    355
# ...

# %%
#convert to integer for sorting
sales_df.rename(columns={"2017-US":"Model"}, inplace=True)
sales_df['JAN'] = pd.to_numeric(sales_df.JAN.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['FEB'] = pd.to_numeric(sales_df.FEB.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['MAR'] = pd.to_numeric(sales_df.MAR.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['APR'] = pd.to_numeric(sales_df.APR.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['MAY'] = pd.to_numeric(sales_df.MAY.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['JUN'] = pd.to_numeric(sales_df.JUN.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['JUL'] = pd.to_numeric(sales_df.JUL.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['AUG'] = pd.to_numeric(sales_df.AUG.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['SEP'] = pd.to_numeric(sales_df.SEP.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['OCT'] = pd.to_numeric(sales_df.OCT.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['NOV'] = pd.to_numeric(sales_df.NOV.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['DEC'] = pd.to_numeric(sales_df.DEC.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df['Total'] = pd.to_numeric(sales_df.Total.astype(str).str.replace(',',''), errors='coerce', downcast='integer')
sales_df.fillna(value=0, inplace=True)
sales_df.head()
# Out:
#                 Model   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 0      Tesla Model S*   900  1150  3450  1125  1620  2350  1425  2150  4860
# 1   Chevrolet Bolt EV  1162   952   918  1292  1566  1642  1911  2101  2632
# 2      Tesla Model X*   150   800  2150   115  1730  2200  1650  1515  3120
# 3  Toyota Prius Prime  1366  1362  1618  1819  1908  1619  1645  1820  1899
# 4      Chevrolet Volt  1611  1820  2132  1801  1811  1145  1518  1445  1453
#
#     OCT   NOV   DEC  Total
# 0  1120  1335  4975  21060
# 1  2181  2981  3227  23291
# 2   850  1815  3300  21315
# 3  1626  1834  2420  20936
# 4  1362  1102  1931  20349

# %%
#sort
clean_df = sales_df.sort_values(by=['Total'], ascending=False)
clean_df.head(50)
# Out:
#                          Model     JAN     FEB     MAR     APR     MAY  \
# 1            Chevrolet Bolt EV  1162.0   952.0   918.0  1292.0  1566.0
# 2               Tesla Model X*   150.0   800.0  2150.0   115.0  1730.0
# 0               Tesla Model S*   900.0  1150.0  3450.0  1125.0  1620.0
# 3           Toyota Prius Prime  1366.0  1362.0  1618.0  1819.0  1908.0
# 4               Chevrolet Volt  1611.0  1820.0  2132.0  1801.0  1811.0
# 5                  Nissan LEAF   112.0  1031.0  1418.0  1063.0  1392.0
# 6           Ford Fusion Energi   606.0   831.0  1002.0   905.0  1000.0
# 7            Ford C-Max Energi   413.0   639.0   662.0   720.0   950.0
# 8                       BMW i3   382.0   318.0   103.0   516.0   506.0
# 9                  Fiat 500e**   152.0   590.0   185.0   541.0   473.0
# 10            BMW X5 xDrive40e   262.0   275.0   397.0   291.0   433.0
# 11  Chrysler Pacifica Hybrid**    12.0     0.0     0.0   335.0   705.0
# ...

# %%
topten_df= clean_df.iloc[0:10]
topten_df.head(10)
# Out:
#                 Model     JAN     FEB     MAR     APR     MAY     JUN     JUL  \
# 1   Chevrolet Bolt EV  1162.0   952.0   918.0  1292.0  1566.0  1642.0  1911.0
# 2      Tesla Model X*   150.0   800.0  2150.0   115.0  1730.0  2200.0  1650.0
# 0      Tesla Model S*   900.0  1150.0  3450.0  1125.0  1620.0  2350.0  1425.0
# 3  Toyota Prius Prime  1366.0  1362.0  1618.0  1819.0  1908.0  1619.0  1645.0
# 4      Chevrolet Volt  1611.0  1820.0  2132.0  1801.0  1811.0  1145.0  1518.0
# 5         Nissan LEAF   112.0  1031.0  1418.0  1063.0  1392.0  1506.0  1283.0
# 6  Ford Fusion Energi   606.0   831.0  1002.0   905.0  1000.0   101.0   103.0
# 7   Ford C-Max Energi   413.0   639.0   662.0   720.0   950.0   936.0   844.0
# 8              BMW i3   382.0   318.0   103.0   516.0   506.0   561.0   601.0
# 9         Fiat 500e**   152.0   590.0   185.0   541.0   473.0   359.0   395.0
#
#       AUG     SEP     OCT     NOV     DEC    Total
# 1  2101.0  2632.0  2181.0  2981.0  3227.0  23291.0
# ...

# %%
totalEV=clean_df["Total"].sum()
bolt=23291
modelX=21315
modelS=21060
toyopp=20936
volt=20349
top5= (bolt + modelX + modelS + toyopp + volt)
others=totalEV-top5
# Out:
# 192986.0

# %%
labels = ["Chevrolet Bolt EV", "Tesla Model X", "Tesla Model S", "Toyota Prius Prime", "Chevrolet Volt", "All Others"]
qtys=[bolt, modelX, modelS, toyopp, volt, others ]
colors = ["red", "blue", 'green', 'yellow', 'purple', 'orange']
explode = (.1, 0,0,0,0,0)
plt.pie(qtys, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=135)
plt.axis("equal")
plt.title("US EV Market")
plt.xlabel("Top 5 Models")
plt.show()
plt.savefig("2017-EV-pie.png")
